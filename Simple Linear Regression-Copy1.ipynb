# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Generate random input data to train on
# Create fake data

# %%
observations = 1000

xs = np.random.uniform(low = -10, high = 10, size = (observations,1))
zs = np.random.uniform(-10, 10, (observations,1))

inputs = np.column_stack((xs, zs))

print (inputs.shape)
# Out:
# (1000, 2)

# %%
inputs
# Out:
# array([[ 0.76404904, -7.66951416],
#        [ 2.48218437, -8.55521553],
#        [-9.28081431,  0.76064308],
#        ...,
#        [-5.56218669, -5.49221795],
#        [-1.04157851, -2.33446211],
#        [-3.59717484,  1.21304057]])

# %% [markdown]
# ## Create the targets we will aim at
# targets = f(x,z) = 2*x - 3*z + 5 + noise
# 2 and 3 are the weights
# 5 is the bias

# %%
noise = np.random.uniform(-1,1,(observations,1))
targets = 13*xs - 7*zs - 12 + noise
print(targets.shape)
# Out:
# (1000, 1)

# %%
targets = targets.reshape(observations)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# ## Initialise Variables

# %%
targets.shape
# Out:
# (1000, 1)

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range, size=(2,1))
biases = np.random.uniform(-init_range, init_range, size=1)

print(weights)
print(biases)
# Out:
# [[-0.01134953]
#  [ 0.04273607]]
# [-0.07195863]

# %% [markdown]
# ## Set a learning Rate

# %%
learning_rate = 0.02

# %% [markdown]
# ## Train the model

# %%
for i in range (1000):
    outputs = np.dot(inputs, weights) + biases
    deltas = outputs - targets
    
    loss = np.sum(deltas **2 ) / 10 / observations
    
    print(loss)
    
    deltas_scaled = deltas / observations
    
    weights = weights - learning_rate * np.dot(inputs.T, deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 746.9232656093159
# 89.52169807571129
# 21.240577323919737
# 13.686974169608835
# 12.446120062310275
# 11.882095818275106
# 11.40645341969736
# 10.956623349300703
# 10.52530838419298
# 10.111102301109444
# 9.713256060176906
# 9.331115698111317
# 8.964060310574796
# 8.611494317933856
# 8.272845744132741
# 7.947565202543768
# 7.635124994672035
# 7.335018252888925
# 7.0467581180043055
# 6.769876949423803
# 6.503925566499465
# 6.248472519829724
# 6.003103391324692
# 5.76742012190119
# 5.54104036571678
# 5.323596869895161
# 5.1147368787367204
# 4.914121561447631
# 4.721425462459135
# 4.536335973445317
# 4.358552826182725
# 4.187787605429267
# 4.0237632810319175
# 3.8662137585044594
# 3.7148834473458527
# 3.5695268463991843
# 3.429908145578413
# 3.295800843316767
# 3.166987379116264
# 3.0432587806022156
# 2.9244143245100904
# 2.8102612110548435
# 2.7006142511543723
# 2.5952955659997317
# 2.4941342984846866
# 2.3969663360265154
# 2.3036340443283274
# 2.21398601165104
# 2.1278768031801203
# ...

# %% [markdown]
# ## Print the weights and biases and see if we have worked correctly

# %%
deltas.shape
# Out:
# (1000, 1)

# %%
print (weights, biases)
# Out:
# [[12.99768045]
#  [-6.99468065]] [-12.00206015]

# %% [markdown]
# ## Plot last outputs vs targets
# Since they are the last ones, they represent final model accuracy.
# This is my new line. Two spaces at the end required...
#
# > The closer this plot is to a 45 degree line,
# > the closer target and output values are.

# %%
plt.plot(outputs, targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
